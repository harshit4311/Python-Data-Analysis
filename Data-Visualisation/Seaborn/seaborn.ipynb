# %%
# !pip install seaborn

print('installation done')
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# installation done

# %%
import seaborn as sns

print('import done')
# Out:
# import done

# %%
# basic plotting with seaborn

tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# create a scatter plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter plot of Total Bill vs Tips")
# Out:
# Text(0.5, 1.0, 'Scatter plot of Total Bill vs Tips')

# %%
# line plot

sns.lineplot(x='size', y='total_bill', data=tips)
plt.title("Line plot for Total Bill vs Size")
# Out:
# Text(0.5, 1.0, 'Line plot for Total Bill vs Size')

# %%
# categorical plots

''' 1. Bar Plot'''

sns.barplot(x='day', y='total_bill', data=tips)
plt.title("bar plot of Total Bill by Day")
# Out:
# Text(0.5, 1.0, 'bar plot of Total Bill by Day')

# %%
''' 2. Box Plot '''

sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
''' 3. Violin Plot '''

sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# histograms

sns.histplot(tips['total_bill'], bins=10, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# KDE plot

sns.kdeplot(tips['total_bill'], fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# pair plot

sns.pairplot(tips)

# %%
# heatmap

''' 1. We first take the correlation between 2-3 quantities, to find relationships between them'''
corr=tips[['total_bill', 'tip', 'size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
''' 2. After finding the correlation, we make a heatmap'''

sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Example testing 

import pandas as pd

sales_df = pd.read_csv('sales_data_sample.csv', encoding='latin1')
sales_df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ...  CONTACTFIRSTNAME  DEALSIZE
# 0           10107               30  ...              Kwai     Small
# 1           10121               34  ...              Paul     Small
# 2           10134               41  ...            Daniel    Medium
# 3           10145               45  ...             Julie    Medium
# 4           10159               49  ...             Julie    Medium
# ...           ...              ...  ...               ...       ...
# 2818        10350               20  ...             Diego     Small
# 2819        10373               29  ...            Pirkko    Medium
# 2820        10386               43  ...             Diego    Medium
# 2821        10397               34  ...           Annette     Small
# 2822        10414               47  ...              Juri    Medium
#
# [2823 rows x 25 columns]

# %%
# plotting total sales by product

plt.figure(figsize=(10,6))
sns.barplot(x='QUANTITYORDERED', y='SALES', data=sales_df, estimator=sum)
# Out:
# <Axes: xlabel='QUANTITYORDERED', ylabel='SALES'>
